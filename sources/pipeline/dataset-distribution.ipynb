# %%
# %run helpers/load_data.ipynb
# Out:
# Dropdown(description='Config:', options=('factory zero', 'knmi'), value='factory zero')
# Tab(children=(VBox(children=(HTML(value='Uploaded file selector:'), HBox(children=(Dropdown(options=('021.xlsx…
# Tab(children=(VBox(children=(VBox(children=(HTML(value='Columns type:'), RadioButtons(options=('features', 'ta…

# %%
df = dfloader.df
df
# Out:
#                      Temperature
# 2018-01-01 00:00:00           78
# 2018-01-01 01:00:00           82
# 2018-01-01 02:00:00           79
# 2018-01-01 03:00:00           79
# 2018-01-01 04:00:00           75
# ...                          ...
# 2020-01-01 19:00:00           26
# 2020-01-01 20:00:00           26
# 2020-01-01 21:00:00           24
# 2020-01-01 22:00:00           19
# 2020-01-01 23:00:00           19
#
# [17544 rows x 1 columns]

# %%
# %matplotlib notebook

fig, ax = plt.subplots(figsize=(12, 6))
plt.hist(df[dfloader.targets[0]], bins=200)
plt.grid(axis="both")
plt.xlabel("Measurement value")
plt.ylabel("Measurement frequency")
title = f"Distribution of {dfloader.targets[0]} ({dfloader.filename.split('/')[-1]})"
plt.title(title)
_ = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
