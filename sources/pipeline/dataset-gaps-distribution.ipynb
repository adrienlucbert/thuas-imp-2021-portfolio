# %%
# %run helpers/load_data.ipynb
# Out:
# Dropdown(description='Config:', options=('factory zero', 'knmi'), value='factory zero')
# ...

# %%
dfloader.add_index_delta_as_feature('timedelta')

df = dfloader.df
df
# Out:
#                      smartMeter_power     timedelta
# Timestamp
# 2018-12-31 23:05:00             246.9  0.000000e+00
# 2018-12-31 23:10:00             249.2  3.000000e+11
# 2018-12-31 23:15:00             250.5  3.000000e+11
# 2018-12-31 23:20:00             248.6  3.000000e+11
# 2018-12-31 23:25:00             246.1  3.000000e+11
# ...                               ...           ...
# 2019-12-31 22:40:00             765.0  3.000000e+11
# 2019-12-31 22:45:00             717.0  3.000000e+11
# 2019-12-31 22:50:00             756.0  3.000000e+11
# 2019-12-31 22:55:00            1168.0  3.000000e+11
# 2019-12-31 23:00:00            1072.0  3.000000e+11
#
# [105091 rows x 2 columns]

# %%
# %matplotlib notebook

fig, ax = plt.subplots(figsize=(12, 6))
plt.yscale("log")
plt.hist(df['timedelta'], bins=100)
plt.grid(axis="both")
plt.xlabel("Measurement value")
plt.ylabel("Measurement frequency")
title = f"Distribution of time difference between observations for {dfloader.targets[0]} ({dfloader.filename.split('/')[-1]})"
plt.title(title)
_ = plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">
